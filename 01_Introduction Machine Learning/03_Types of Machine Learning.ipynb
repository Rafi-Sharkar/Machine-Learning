# %% [markdown]
# ## Type of ML
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Supervised Learning
# #### If I have input and output both
# #### data the it is Supervised Learning.
# #### Supervised has two type:
#    ####  1. Regression(Output data Numerical)
#    ####  2. Classification(Output data Categorical)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Unsupervised Learning
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Reinforcement learning
# ![image.png](attachment:image.png)
