# %% [markdown]
# ## Diagram of AI, ML, DL, DS
# ![image.png](attachment:image.png)

# %% [markdown]
# ## What is intelligence?
# #### - Intelligence is the ability to learn, understand, and use knowledge to solve problems and make decisions.

# %% [markdown]
# ## Deep Learning
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Conclusion: To make AI we require to ML. For better output we use DL which is a part of ML.
