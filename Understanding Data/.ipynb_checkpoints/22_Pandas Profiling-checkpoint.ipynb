# %%
import pandas as pd
df = pd.read_csv('titanic_dataset.csv')
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                       Name     Sex   Age  \
# 337         1229         0       3          Elias, Mr. Joseph    male  39.0
# 315         1207         1       3       Hagardon, Miss. Kate  female  17.0
# 173         1065         0       3           Torfa, Mr. Assad    male   NaN
# 310         1202         0       3       Cacic, Mr. Jego Grga    male  18.0
# 228         1120         0       3  Everett, Mr. Thomas James    male  40.5
#
#      SibSp  Parch       Ticket     Fare Cabin Embarked
# 337      0      2         2675   7.2292   NaN        C
# 315      0      0  AQ/3. 30631   7.7333   NaN        Q
# 173      0      0         2673   7.2292   NaN        C
# 310      0      0       315091   8.6625   NaN        S
# 228      0      0    C.A. 6212  15.1000   NaN        S

# %%
# Out:
# Requirement already satisfied: ydata-profiling in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (4.12.2)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.11.4)
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (2.0.2)
# Requirement already satisfied: matplotlib>=3.5 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (3.8.0)
# Requirement already satisfied: pydantic>=2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (2.10.6)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (6.0)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (3.1.2)
# Requirement already satisfied: visions<0.8.0,>=0.7.5 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (0.7.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.26.2)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.12.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (2.31.0)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.13.2)
# Requirement already satisfied: multimethod<2,>=1.4 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.12)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (0.14.4)
# Requirement already satisfied: typeguard<5,>=3 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (4.4.1)
# Requirement already satisfied: imagehash==4.3.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (4.3.1)
# Requirement already satisfied: wordcloud>=1.9.3 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.9.4)
# Requirement already satisfied: dacite>=1.8 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling) (1.9.1)
# Requirement already satisfied: PyWavelets in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.8.0)
# Requirement already satisfied: pillow in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from matplotlib>=3.5->ydata-profiling) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2->ydata-profiling) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2->ydata-profiling) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2->ydata-profiling) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2023.11.17)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (1.0.1)
# Requirement already satisfied: colorama in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (23.1.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from visions<0.8.0,>=0.7.5->visions[type_image_path]<0.8.0,>=0.7.5->ydata-profiling) (3.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\msi\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.5->ydata-profiling) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# importing packages
import pandas as pd
from pandas_profiling import ProfileReport
profile = ProfileReport(data)
profile
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[9], line 3
#       1 # importing packages
#       2 import pandas as pd
# ----> 3 from pandas_profiling import ProfileReport
#       4 profile = ProfileReport(data)
#       5 profile
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
#       8 from pandas_profiling.profile_report import ProfileReport
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas_profiling\config.py:7
#       4 from typing import Any, Dict, List, Optional, Tuple, Union
#       6 import yaml
# ----> 7 from pydantic import BaseModel, BaseSettings, Field, PrivateAttr
#      10 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#      11     """
#      12     Recursive merge dictionaries.
#      13
#    (...)
#      16     :return: Merged dictionary
#      17     """
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\__init__.py:412, in __getattr__(attr_name)
#     410 dynamic_attr = _dynamic_imports.get(attr_name)
#     411 if dynamic_attr is None:
# --> 412     return _getattr_migration(attr_name)
#     414 package, module_name = dynamic_attr
#     416 if module_name == '__module__':
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydantic\_migration.py:296, in getattr_migration.<locals>.wrapper(name)
#     294     return import_string(REDIRECT_TO_V1[import_path])
#     295 if import_path == 'pydantic:BaseSettings':
# --> 296     raise PydanticImportError(
#     297         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     298         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     299         'for more details.'
#     300     )
#     301 if import_path in REMOVED_IN_V2:
#     302     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.10/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.10/u/import-error
