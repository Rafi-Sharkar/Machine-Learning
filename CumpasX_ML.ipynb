# %% [markdown]
# <a href="https://colab.research.google.com/github/Rafi-Sharkar/Machine-Learning/blob/main/CumpasX_ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Type of ML

# %%
print("Type of Machine Learning")
# Out:
# Type of Machine Learning
