# %% [markdown]
# ## Encoding Categorical Variables
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Ordinal Encoding
# ![image.png](attachment:image.png)

# %% [markdown]
# # Example

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('customer.csv')

# %%
df.sample(5)
# Out:
#     age  gender review education purchased
# 31   22  Female   Poor    School       Yes
# 22   18  Female   Poor        PG       Yes
# 47   38  Female   Good        PG       Yes
# 12   51    Male   Poor    School        No
# 19   97    Male   Poor        PG       Yes

# %%
 df=df.iloc[:,2:]

# %%
df.head()
# Out:
#     review education purchased
# 0  Average    School        No
# 1     Poor        UG        No
# 2     Good        PG        No
# 3     Good        PG        No
# 4  Average        UG        No

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.iloc[:,0:2],df.iloc[:,-1],test_size=.02)

# %%
X_train
# Out:
#      review education
# 49     Good        UG
# 45     Poor        PG
# 44  Average        UG
# 46     Poor        PG
# 40     Good    School
# 0   Average    School
# 28     Poor    School
# 6      Good    School
# 47     Good        PG
# 12     Poor    School
# 33     Good        PG
# 39     Poor        PG
# 2      Good        PG
# 14     Poor        PG
# 17     Poor        UG
# 16     Poor        UG
# 41     Good        PG
# 36     Good        UG
# 35     Poor    School
# 48     Good        UG
# 1      Poor        UG
# 31     Poor    School
# 38     Good    School
# 24  Average        PG
# 18     Good    School
# 15     Poor        UG
# 29  Average        UG
# 4   Average        UG
# 21  Average        PG
# 11     Good        UG
# 7      Poor    School
# 13  Average    School
# 19     Poor        PG
# 3      Good        PG
# 23     Good    School
# 5   Average    School
# 8   Average        UG
# 42     Good        PG
# 43     Poor        PG
# 9      Good        UG
# 22     Poor        PG
# 25     Good    School
# 37  Average        PG
# 30  Average        UG
# 34  Average    School
# 10     Good        UG
# 26     Poor        PG
# 27     Poor        PG
# 32  Average        UG

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oe = OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
oe
# Out:
# OrdinalEncoder(categories=[['Poor', 'Average', 'Good'], ['School', 'UG', 'PG']])

# %%
oe.fit(X_train)

# %%
X_train = oe.transform(X_train)

# %%
X_train

# %%
oe.categories_

# %%
X_train

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
le.fit(y_train)

# %%
le.classes_

# %%
y_train = le.transform(y_train)
y_test = le.transform(y_test)

# %%
y_train
