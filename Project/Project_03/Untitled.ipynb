# %% [markdown]
# # Fetching Dataset

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Flatten,Dense

# %%
(X_img, Y_img),(X_lab,Y_lab) = keras.datasets.mnist.load_data()

# %%
print(X_img.shape)
print(Y_img.shape)
print(X_lab.shape)
print(Y_lab.shape)
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)

# %%
nl_img = X_img/255
nl_lab = X_lab/255

# %%
model = Sequential()

# %%
model.add(Flatten(input_shape=(28,28)))
model.add(Dens(128, activation='relu'))
model.add(Dese())
